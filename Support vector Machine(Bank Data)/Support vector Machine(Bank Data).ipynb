# %%
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r"F:\WORK\Machine Learning\Support vector Machine(Bank Data)\UCI_Credit_Card.csv")
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
df.groupby('default.payment.next.month').mean()
# Out:
#                                       ID      LIMIT_BAL       SEX  EDUCATION  \
# default.payment.next.month
# 0                           15064.893982  178099.726074  1.614150   1.841337
# 1                           14773.781947  130109.656420  1.567058   1.894665
#
#                             MARRIAGE        AGE     PAY_0     PAY_2     PAY_3  \
# default.payment.next.month
# 0                           1.558637  35.417266 -0.211222 -0.301917 -0.316256
# 1                           1.528029  35.725738  0.668174  0.458258  0.362116
#
#                                PAY_4  ...     BILL_AMT3     BILL_AMT4  \
# default.payment.next.month            ...
# 0                          -0.355633  ...  47533.365605  43611.165254
# 1                           0.254521  ...  45181.598855  42036.950573
#
#                                BILL_AMT5     BILL_AMT6     PAY_AMT1  \
# default.payment.next.month
# 0                           40530.445343  39042.268704  6307.337357
# ...

# %%
payment=df[df['default.payment.next.month']==1]
payment.shape
# Out:
# (6636, 25)

# %%
not_pay=df[df['default.payment.next.month']==0]
not_pay.shape
# Out:
# (23364, 25)

# %%
payment
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 13        14    70000.0    1          2         2   30      1      2      2
# 16        17    20000.0    1          1         2   24      0      0      2
# 21        22   120000.0    2          2         1   39     -1     -1     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29991  29992   210000.0    1          2         1   34      3      2      2
# 29994  29995    80000.0    1          2         2   34      2      2      2
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
pd.crosstab(df.SEX,df['default.payment.next.month']).plot(kind='bar')

# %%
pd.crosstab(df.EDUCATION,df['default.payment.next.month']).plot(kind='bar')

# %%
pd.crosstab(df.MARRIAGE,df['default.payment.next.month']).plot(kind='bar')

# %%
pd.crosstab(df.AGE,df['default.payment.next.month']).plot(kind='bar')

# %%
pd.crosstab(df.LIMIT_BAL,df['default.payment.next.month']).plot(kind='bar')
